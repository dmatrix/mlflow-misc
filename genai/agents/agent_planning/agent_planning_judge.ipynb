# %% [markdown]
# # LLM-as-a-Judge Tutorial: Multi-Step Planning Evaluation with MLflow
#
# This interactive notebook demonstrates how to use MLflow's LLM-as-a-Judge pattern to evaluate AI agent planning decisions.
#
# ## Tutorial Goals
#
# 1. Use MLflow tracing to capture agent planning actions
# 2. Create a judge using `mlflow.genai.judges.make_judge()`
# 3. Evaluate multi-step plans using the judge
# 4. Integrate with MLflow experiments for reproducibility
#
# ## Scenario
#
# An AI agent creates a multi-step plan to accomplish a task using available resources. The judge evaluates whether the plan is logical, complete, efficient, and uses valid tools.
#
# **Evaluation Criteria:**
# - Logical step ordering: Are steps in the correct sequence?
# - Tool validity: Are only valid, available tools used?
# - Task sufficiency: Will the plan accomplish the goal?
# - Efficiency: Is the approach optimal?
#
#
# ┌─────────────────────────────────────────────────────────┐
# │ 1. Agent creates plan (plain text, numbered steps)      │
# │    - LLM generates: "1. Search flights 2. Book flight"  │
# └─────────────────────────────────────────────────────────┘
#
# ┌─────────────────────────────────────────────────────────┐
# │ 2. Executor parses plan into steps                      │
# └─────────────────────────────────────────────────────────┘
#
# ┌─────────────────────────────────────────────────────────┐
# │ 3. FOR EACH STEP:                                       │
# │    a) LLM receives: step description, tool schemas,     │
# │       context from previous steps                       │
# │    b) LLM uses function calling to select tool and      │
# │       determine parameters                              │
# │    c) Executor calls the selected tool                  │
# └─────────────────────────────────────────────────────────┘
#
# ---
#
# Based on the [tool_selection_judge.py](../tools_selection/tool_selection_judge.py) pattern and adapted for planning evaluation.

# %% [markdown]
# ## Setup: Import Dependencies
#
# First, let's import all the necessary libraries.

# %%
from genai.common.config import AgentConfig
from genai.agents.agent_planning.prompts import get_judge_instructions, get_planning_prompt
import mlflow
from typing import List
import os
from pathlib import Path

# Load environment variables from .env file if it exists
try:
    from dotenv import load_dotenv
    env_file = Path(".env")
    if env_file.exists():
        load_dotenv(env_file)
        print(f"✓ Loaded environment variables from {env_file.absolute()}")
    else:
        print(f"ℹ️  No .env file found at {env_file.absolute()}")
        print("   You can create one with your credentials or set environment variables manually")
except ImportError:
    print("ℹ️  python-dotenv not installed. Install with: pip install python-dotenv")
    print("   Or set environment variables manually in the cells below")
# Out:
# ✓ Loaded environment variables from /Users/jules/git-repos/mlflow-misc/genai/agents/agent_planning/.env

# %% [markdown]
# ## Configuration: Set Up Environment
#
# **Two ways to configure credentials:**
#
# 1. **Recommended**: Create a `.env` file in this directory with your credentials
# 2. **Alternative**: Uncomment and set credentials in the cells below
#
# ### Create a `.env` file (Recommended)
#
# Create a file named `.env` in the same directory as this notebook:
#
# **For Databricks:**
# ```
# DATABRICKS_TOKEN=your-token-here
# DATABRICKS_HOST=https://your-workspace.cloud.databricks.com
# ```
#
# **For OpenAI:**
# ```
# OPENAI_API_KEY=sk-your-key-here
# ```
#
# The cell above will automatically load these credentials.

# %%
# ============================================================================
# CONFIGURATION: Choose your provider and models
# ============================================================================

# Option 1: Databricks (default)
PROVIDER = "databricks"
AGENT_MODEL = "databricks-gpt-5"
JUDGE_MODEL = "databricks-gemini-2-5-flash"

# Option 2: OpenAI (uncomment to use)
# PROVIDER = "openai"
# AGENT_MODEL = "gpt-4o-mini"
# JUDGE_MODEL = "gpt-4o"

# Other settings
TEMPERATURE = 1.0
EXPERIMENT_NAME = "agent-planning-judge-notebook"

print("✓ Configuration set:")
print(f"  Provider: {PROVIDER}")
print(f"  Agent Model: {AGENT_MODEL}")
print(f"  Judge Model: {JUDGE_MODEL}")
# Out:
# ✓ Configuration set:
#   Provider: databricks
#   Agent Model: databricks-gpt-5
#   Judge Model: databricks-gemini-2-5-flash

# %% [markdown]
# ### Verify Credentials (Optional Manual Setup)
#
# If you didn't create a `.env` file, you can set credentials manually by uncommenting the appropriate lines below:

# %%
# ============================================================================
# MANUAL CREDENTIAL SETUP (if not using .env file)
# ============================================================================

# For Databricks - Uncomment and set these if you didn't create a .env file
# os.environ["DATABRICKS_TOKEN"] = "your-token-here"
# os.environ["DATABRICKS_HOST"] = "https://your-workspace.cloud.databricks.com"

# For OpenAI - Uncomment and set this if you didn't create a .env file
# os.environ["OPENAI_API_KEY"] = "sk-your-key-here"

# Verify credentials are set
if PROVIDER == "databricks":
    if "DATABRICKS_TOKEN" in os.environ and "DATABRICKS_HOST" in os.environ:
        print("✓ Databricks credentials found")
    else:
        print("⚠️  Missing Databricks credentials!")
        print("   Create a .env file or uncomment the lines above to set credentials")
elif PROVIDER == "openai":
    if "OPENAI_API_KEY" in os.environ:
        print("✓ OpenAI credentials found")
    else:
        print("⚠️  Missing OpenAI credentials!")
        print("   Create a .env file or uncomment the lines above to set credentials")
# Out:
# ✓ Databricks credentials found

# %% [markdown]
# ## Step 1: Setup MLflow Tracing
#
# Enable MLflow tracing to capture all agent planning actions and LLM calls automatically.

# %%
from genai.common.mlflow_config import setup_mlflow_tracking

setup_mlflow_tracking(
    experiment_name=EXPERIMENT_NAME,
    enable_autolog=True
)

print("✓ MLflow tracing enabled")
print(f"  Experiment: {EXPERIMENT_NAME}")
print("  View traces: mlflow ui")
# Out:
# 2025/12/01 13:08:15 INFO mlflow.tracking.fluent: Experiment with name 'agent-planning-judge-notebook' does not exist. Creating a new experiment.
# ✓ MLflow tracing enabled
#   Experiment: agent-planning-judge-notebook
#   View traces: mlflow ui

# %% [markdown]
# ## Step 2: Import the Agent Class
#
# Instead of redefining the class, we import it directly from the module to follow DRY principles.

# %%
# Import the AgentPlanningJudge class from the module
from genai.agents.agent_planning import AgentPlanningJudge

print("✓ AgentPlanningJudge imported successfully")
print("\nThe class provides:")
print("  - create_plan(): Generate multi-step plans")
print("  - evaluate(): Judge plan quality using MLflow")
print("  - execute_plan_with_tools(): Execute plans with actual tool calls")
# Out:
# ✓ AgentPlanningJudge imported successfully
#
# The class provides:
#   - create_plan(): Generate multi-step plans
#   - evaluate(): Judge plan quality using MLflow
#   - execute_plan_with_tools(): Execute plans with actual tool calls

# %% [markdown]
# ## Step 2: Initialize Agent and Judge
#
# Create the configuration and instantiate our planning judge.

# %%
# Create agent configuration
config = AgentConfig(
    model=AGENT_MODEL,
    provider=PROVIDER,
    temperature=TEMPERATURE
)

# Initialize the judge
judge = AgentPlanningJudge(config, judge_model=JUDGE_MODEL)

print("✓ Agent and Judge initialized")
print(f"  Provider: {config.provider}")
print(f"  Agent Model: {config.model}")
print(f"  Judge Model: {JUDGE_MODEL}")
print(f"  Temperature: {config.temperature}")
# Out:
# ✓ Agent and Judge initialized
#   Provider: databricks
#   Agent Model: databricks-gpt-5
#   Judge Model: databricks-gemini-2-5-flash
#   Temperature: 1.0

# %% [markdown]
# ## Step 3: Define Planning Scenario
#
# Set up a task goal and available resources for the agent to plan with.
#
# **💡 Try different task goals to see how the agent plans and how the judge evaluates!**

# %%
# Define the scenario
task_goal = "Book a flight from NYC to SF for next Tuesday and add to calendar"
available_resources = [
    "flight_search_api",
    "booking_api",
    "calendar_api",
    "hotel_search_api",
    "email_api"
]

print("Planning Scenario:")
print(f"  Task Goal: {task_goal}")
print(f"  Available Resources: {available_resources}")
# Out:
# Planning Scenario:
#   Task Goal: Book a flight from NYC to SF for next Tuesday and add to calendar
#   Available Resources: ['flight_search_api', 'booking_api', 'calendar_api', 'hotel_search_api', 'email_api']

# %% [markdown]
# ### 💡 Try Different Task Goals
#
# Uncomment one of these examples or write your own:

# %%
# Example task goals to try:
# task_goal = "Send confirmation email after booking flight"
# available_resources = ["email_api", "flight_search_api", "booking_api"]

# task_goal = "Find and book a hotel in Paris for next month"
# available_resources = ["hotel_search_api", "booking_api", "email_api"]

# task_goal = "Book flight and add travel event to calendar"
# available_resources = ["calendar_api", "flight_search_api", "booking_api", "email_api"]

# %% [markdown]
# ## Step 4: Agent Creates Plan
#
# The agent creates a multi-step plan based on the task goal. MLflow automatically traces this action.

# %%
print("\n[Step 4] Agent creates a multi-step plan using LLM...")

plan = judge.create_plan(task_goal, available_resources)

print("  └─ ✓ Plan created:\n")
# Indent the plan for better readability
for line in plan.split('\n'):
    if line.strip():
        print(f"      {line}")
# Out:
# [Step 4] Agent creates a multi-step plan...
#   └─ ✓ Plan created:
#
#       1. flight_search_api: Query round-trip vs one-way options as needed; search one-way flights from NYC (aggregate JFK, LGA, EWR) to San Francisco (SFO; include OAK/SJC as alternates if permitted) for next Tuesday. Include parameters: earliest/ latest departure windows, nonstop preference, baggage allowance, fare class (e.g., Main/Economy), seat type, refundability, and price cap if any. Request outputs: flight number, airline, depart/arrive airports and times (local), duration, number of stops, layover details, fare rules, total price, baggage fees, and booking class.
#       2. flight_search_api: Filter results to match constraints (nonstop preferred, reasonable depart window, best price vs duration tradeoff). Sort by total travel time then price; exclude red-eyes unless specified.
#       3. flight_search_api: Fetch seat map and remaining seat availability for the top 3 candidate flights; confirm baggage inclusion and change/cancel policies.
#       4. email_api: If user confirmation is required, draft and send a summary of top 3 options with key details (times, airports, duration, price, policies) and a request for approval. Otherwise, proceed with the best option per criteria.
#       5. booking_api: Create a booking for the selected flight. Provide passenger details (full name, DOB, gender), contact info, known traveler/redress numbers, seat preference, frequent flyer number, and payment details (card info, billing address). Select seats per preference and include 1 carry-on + 1 checked bag if needed.
#       6. booking_api: Confirm booking; retrieve PNR/record locator, ticket number, final itinerary, baggage receipt, fare rules, and invoice.
#       7. calendar_api: Create a calendar event for departure. Title: “Flight: NYC to SF (Airline FlightNumber).” Start: departure local time; End: arrival local time; Time zone-aware. Location: departure airport code and terminal. Description: include full itinerary, PNR, seat, confirmation number, baggage allowance, fare class, and check-in link. Set reminders: 24 hours and 3 hours before departure.
#       8. calendar_api: If a return is implied, create a separate event for the return flight similarly; otherwise, skip.
#       9. email_api: Send booking confirmation summary email to the user with the itinerary, calendar invite (.ics from calendar_api if supported), check-in instructions, and airline manage-booking link.
#       10. flight_search_api: Optional backup monitoring—set a price/upgrade alert for the same flight or alternates in case of schedule change or seat upgrade opportunities.
# Trace(trace_id=tr-97433e60567320d62d88d7ec5bf0e7b4)

# %% [markdown]
# ## Step 5: Judge Evaluates the Plan
#
# Now the judge evaluates the plan quality on multiple dimensions.

# %%
print("\n[Step 5] The LLM Judge evaluates the plan quality...")

# Get the trace ID from the agent's action
trace_id = mlflow.get_last_active_trace_id()

# Evaluate with the judge
result = judge.evaluate(trace_id)

# Display results
print("\n[Step 6] Evaluation Results")
print("=" * 70)
print(f"Quality: {result['quality'].upper()} (Score: {result['score']}/5)")
print("\nDetailed Assessment:")
print(f"{result['reasoning']}")
print("=" * 70)
# Out:
# [Step 5] Judge evaluates the plan quality...
#
# [Step 6] Evaluation Results
# ======================================================================
# Quality: EXCELLENT (Score: 5/5)
#
# Detailed Assessment:
# The plan demonstrates excellent quality across all criteria:
#
# **1. Logical Step Ordering: Excellent**
# The steps are ordered perfectly, building logically from searching for flights, filtering options, seeking user confirmation (a crucial step), performing the actual booking, confirming details, adding to the calendar, and finally sending a comprehensive confirmation email. The inclusion of an optional monitoring step at the end is also well-placed. Each step naturally follows the previous one, ensuring a smooth and effective workflow.
#
# **2. Tool Validity: Excellent**
# All tools used (`flight_search_api`, `email_api`, `booking_api`, `calendar_api`) are explicitly listed as available resources. There are no hallucinated or invalid tools. The plan correctly identifies which tool is appropriate for each specific action.
#
# **3. Task Sufficiency: Excellent**
# The plan comprehensively addresses the task goal of 'Book a flight from NYC to SF for next Tuesday and add to calendar'.
# *   **Flight Booking:** Steps 1-6 meticulously cover the flight search (including detailed parameters and alternate airports), filtering, fetching seat availability, obtaining user confirmation, and the actual booking process with all necessary passenger and payment details, culminating in the retrieval of booking confirmations.
# *   **Calendar Integration:** Steps 7-8 ensure the flight details are added to the calendar with appropriate title, times, location, and reminders. The conditional for a return flight is a thoughtful addition.
# *   **Post-Booking Communication:** Step 9 ensures the user receives a detailed confirmation email with all relevant information and links. Step 10 provides an optional but valuable monitoring service.
#
# **4. Efficiency: Excellent**
# The plan is highly efficient, avoiding redundant actions while being thorough. The detailed search parameters, filtering, and confirmation steps are necessary to ensure accuracy and user satisfaction, not inefficiencies. Fetching seat maps for the top 3 candidates is a reasonable approach to provide options without over-processing. The optional monitoring step is a value-add, not a core inefficiency. The plan balances thoroughness with a streamlined process.
#
# **Strengths of the plan:**
# *   **Comprehensive Detail:** The plan specifies detailed parameters for each API call, ensuring a robust and accurate execution (e.g., specific flight search parameters, passenger details for booking, detailed calendar event fields).
# *   **User-Centric:** The inclusion of user confirmation (Step 4) and a detailed confirmation email (Step 9) demonstrates a strong focus on user experience and preventing errors.
# *   **Robustness:** Considering alternate airports (JFK, LGA, EWR for NYC; SFO, OAK, SJC for SF) and handling potential return flights (Step 8) makes the plan adaptable.
# *   **Error Prevention:** Confirming baggage inclusion and change/cancel policies (Step 3) and retrieving all booking identifiers (PNR, ticket number) are excellent practices.
#
# **Weaknesses or gaps identified:**
# *   None significant. The plan is exceptionally well-thought-out.
#
# **Specific suggestions for improvement:**
# *   While already excellent, for an even more advanced plan, one *could* consider a step to proactively handle payment failures or booking re-attempts, but this might be beyond the scope of a typical planning task.
#
# Overall, this plan is a model of excellence, demonstrating clear structure, logical flow, optimal efficiency, and comprehensive task sufficiency using valid tools.
# ======================================================================
# [Trace(trace_id=tr-d62127b97bc216e83a9ef8eaf7d10f21), Trace(trace_id=tr-5dc537ad0e993dc3175c3ed045241110), Trace(trace_id=tr-9f7c9f9189acda58871c3654207db76b)]

# %% [markdown]
# ## Step 7: Execute Plan with Actual Tools
#
# Now we'll execute the plan using actual (simulated) tools. This demonstrates the complete multi-agent workflow where the LLM dynamically selects which tools to call for each step.

# %%
print("\n[Step 7] Executing plan with actual tools...")
print("=" * 70)

# Execute the plan
execution_result = judge.execute_plan_with_tools(plan, task_goal)

print("\n  ✓ Execution Complete!")
print(f"  └─ Total Steps: {execution_result['total_steps']}")
print(f"  └─ Successful: {execution_result['successful_steps']}/{execution_result['total_steps']}")

print("\n  Step-by-Step Results:")
for step_result in execution_result['step_results']:
    step_num = step_result['step_number']
    tool = step_result.get('tool_used', 'No tool')
    success = '✓' if step_result.get('success') else '✗'
    
    print(f"  {success} Step {step_num}: {tool}")
    if step_result.get('result'):
        result_preview = str(step_result['result'])[:100]
        print(f"     Result: {result_preview}...")

print("=" * 70)
# Out:
# [Step 7] Executing plan with actual tools...
# ======================================================================
#
#   Executing 10 steps...
#   └─ Step 1/10: flight_search_api: Query round-trip vs one-way options as ne...
#      ✓ Used flight_search_api
#   └─ Step 2/10: flight_search_api: Filter results to match constraints (nons...
#      ✓ Used flight_search_api
#   └─ Step 3/10: flight_search_api: Fetch seat map and remaining seat availab...
#      ✓ Used flight_search_api
#   └─ Step 4/10: email_api: If user confirmation is required, draft and send ...
#      ✓ Used email_api
#   └─ Step 5/10: booking_api: Create a booking for the selected flight. Provi...
#      ✓ Used booking_api
#   └─ Step 6/10: booking_api: Confirm booking; retrieve PNR/record locator, t...
#      ✓ Used booking_api
#   └─ Step 7/10: calendar_api: Create a calendar event for departure. Title: ...
#      ✓ Used calendar_api
#   └─ Step 8/10: calendar_api: If a return is implied, create a separate even...
#   └─ Step 9/10: email_api: Send booking confirmation summary email to the us...
#      ✓ Used email_api
#   └─ Step 10/10: flight_search_api: Optional backup monitoring—set a price/up...
#
#   ✓ Execution Complete!
#   └─ Total Steps: 10
#   └─ Successful: 10/10
#
#   Step-by-Step Results:
#   ✓ Step 1: flight_search_api
#      Result: [{'flight_id': 'FL6254', 'airline': 'Southwest', 'origin': 'NYC', 'destination': 'SFO', 'date': '202...
#   ✓ Step 2: flight_search_api
#      Result: [{'flight_id': 'FL9361', 'airline': 'Delta', 'origin': 'NYC', 'destination': 'SFO', 'date': '2025-12...
#   ✓ Step 3: flight_search_api
#      Result: [{'flight_id': 'FL7367', 'airline': 'Southwest', 'origin': 'NYC', 'destination': 'SFO', 'date': '202...
#   ✓ Step 4: email_api
#      Result: {'message_id': 'MSG622622', 'to': 'user@example.com', 'subject': 'ACTION REQUIRED: Top 3 flight opti...
#   ✓ Step 5: booking_api
#      Result: {'booking_id': 'BK50261', 'flight_id': 'FL9361', 'passenger_name': 'REQUIRED', 'passenger_email': 'R...
#   ✓ Step 6: booking_api
#      Result: {'booking_id': 'BK21235', 'flight_id': 'FL9361', 'passenger_name': 'REQUIRED', 'passenger_email': 'R...
#   ✓ Step 7: calendar_api
#      Result: {'event_id': 'EVT1668', 'title': 'Flight: NYC to SF (Delta FL9361)', 'start_time': '2025-12-09T02:30...
#   ✓ Step 8: None
#      Result: No tool execution needed...
#   ✓ Step 9: email_api
#      Result: {'message_id': 'MSG676601', 'to': 'user@example.com', 'subject': 'Your Flight Booking Confirmation: ...
#   ✓ Step 10: None
#      Result: No tool execution needed...
# ======================================================================
# Trace(trace_id=tr-34ee5f3c21a85bc54e385f90e74fec4e)

# %% [markdown]
# ## 🎯 Try It Yourself!
#
# Run the complete workflow (Plan → Evaluate → Execute) with a custom task:

# %%
def run_complete_workflow(task: str, resources: List[str]):
    """
    Complete workflow: Agent creates plan (using a provider LLM) → LLM Judge evaluates → Agent Execute with tools
    """
    print(f"\n{'='*70}")
    print(f"Task Goal: {task}")
    print(f"Available Resources: {resources}")
    print(f"{'='*70}\n")
    
    # Step 1: Agent creates plan
    print("📝 Creating plan...")
    plan = judge.create_plan(task, resources)
    print("\n✓ Plan created:")
    for line in plan.split('\n'):
        if line.strip():
            print(f"  {line}")
    
    # Step 2: Judge evaluates plan quality
    print("\n⚖️  Evaluating plan quality...")
    trace_id = mlflow.get_last_active_trace_id()
    eval_result = judge.evaluate(trace_id)
    
    print(f"\n✓ Quality: {eval_result['quality'].upper()} (Score: {eval_result['score']}/5)")
    print(f"  Assessment: {eval_result['reasoning'][:150]}...")
    
    # Step 3: Execute plan with actual tools
    print("\n🔧 Executing plan with tools...")
    exec_result = judge.execute_plan_with_tools(plan, task)
    
    print(f"\n✓ Execution: {exec_result['successful_steps']}/{exec_result['total_steps']} steps successful")
    for step_result in exec_result['step_results']:
        if step_result.get('tool_used'):
            success = "✓" if step_result.get('success') else "✗"
            print(f"  {success} Step {step_result['step_number']}: {step_result['tool_used']}")
    
    print(f"\n{'='*70}\n")
    
    return {
        "evaluation": eval_result,
        "execution": exec_result
    }

# Try the complete workflow!
result = run_complete_workflow(
    task="Book a flight to Boston and send confirmation email",
    resources=["flight_search_api", "booking_api", "email_api"]
)
# Out:
# ======================================================================
# Task Goal: Book a flight to Boston and send confirmation email
# Available Resources: ['flight_search_api', 'booking_api', 'email_api']
# ======================================================================
#
# 📝 Creating plan...
#
# ✓ Plan created:
#   1. Gather trip details from user (origin city/airport, destination: Boston [BOS], departure date/time window, return date if round-trip, number of passengers, cabin class, baggage needs, seating preferences, max budget, flexibility).
#   2. Call flight_search_api with collected parameters to retrieve available flight options to BOS (and back if round-trip), including total price, fare rules, baggage, layovers, and change/cancellation policies.
#   3. Parse and rank results by user priorities (price, duration, number of stops, airline, departure/arrival times) and filter out options that violate constraints (budget, baggage, long layovers).
#   4. Present top 3–5 flight options to user with key details and prices; confirm final selection and passenger details (full legal name(s), DOB, gender if required, known traveler/redress numbers, frequent flyer numbers), and confirm payment method.
#   5. Re-validate availability and price by calling flight_search_api for the selected itinerary to ensure no changes since initial search.
#   6. Create a booking request payload with selected itinerary and passenger data; include seat preferences and loyalty numbers.
#   7. Call booking_api to place the booking on hold if supported; capture hold locator and hold expiration time.
#   8. If hold not supported or after hold creation, confirm final authorization to ticket; collect/confirm billing details (card number/token, expiration, CVV, billing address) via secure channel.
#   9. Call booking_api to ticket the reservation using the confirmed payment method; request e-ticket issuance and seat assignment if available.
#   10. Verify booking success by checking booking_api response for PNR/record locator, e-ticket numbers, final price charged, and ticket status.
#   11. Retrieve full itinerary and receipt details (flight segments, times, terminals, baggage allowance, seat numbers, fare rules, change/cancel policy) from booking_api.
#   12. Construct a confirmation email body with passenger names, PNR, e-ticket numbers, itinerary, seats, baggage info, check-in instructions, and support/contact info; attach receipt if available.
#   13. Call email_api to send the confirmation email to the user’s email address; set subject line including airline and PNR, and request delivery/read receipts if supported.
#   14. Call email_api to send calendar invites (.ics) for each flight segment, if supported, to the user’s email.
#   15. Call email_api to send a separate summary to any additional recipients authorized by the user (e.g., traveling companions), redacting payment details.
#   16. Call booking_api to subscribe the PNR to schedule change alerts if available; otherwise set a reminder to re-check 24 hours before departure.
#   17. Call email_api to send a final status email confirming successful booking, what to expect next (e.g., online check-in window), and how to modify/cancel if needed.
#
# ⚖️  Evaluating plan quality...
#
# ✓ Quality: GOOD (Score: 4/5)
#   Assessment: The plan demonstrates a strong understanding of the task requirements and outlines a comprehensive, step-by-step approach. It covers all necessary asp...
#
# 🔧 Executing plan with tools...
#
#   Executing 17 steps...
#   └─ Step 1/17: Gather trip details from user (origin city/airport, destinat...
#   └─ Step 2/17: Call flight_search_api with collected parameters to retrieve...
#      ✓ Used flight_search_api
#   └─ Step 3/17: Parse and rank results by user priorities (price, duration, ...
#   └─ Step 4/17: Present top 3–5 flight options to user with key details and ...
#   └─ Step 5/17: Re-validate availability and price by calling flight_search_...
#      ✓ Used flight_search_api
#   └─ Step 6/17: Create a booking request payload with selected itinerary and...
#   └─ Step 7/17: Call booking_api to place the booking on hold if supported; ...
#      ✓ Used booking_api
#   └─ Step 8/17: If hold not supported or after hold creation, confirm final ...
#   └─ Step 9/17: Call booking_api to ticket the reservation using the confirm...
#      ✓ Used booking_api
#   └─ Step 10/17: Verify booking success by checking booking_api response for ...
#      ✓ Used booking_api
#   └─ Step 11/17: Retrieve full itinerary and receipt details (flight segments...
#      ✓ Used booking_api
#   └─ Step 12/17: Construct a confirmation email body with passenger names, PN...
#      ✓ Used email_api
#   └─ Step 13/17: Call email_api to send the confirmation email to the user’s ...
#      ✓ Used email_api
#   └─ Step 14/17: Call email_api to send calendar invites (.ics) for each flig...
#      ✓ Used email_api
#   └─ Step 15/17: Call email_api to send a separate summary to any additional ...
#      ✓ Used email_api
#   └─ Step 16/17: Call booking_api to subscribe the PNR to schedule change ale...
#      ✓ Used booking_api
#   └─ Step 17/17: Call email_api to send a final status email confirming succe...
#      ✓ Used email_api
#
# ✓ Execution: 17/17 steps successful
#   ✓ Step 2: flight_search_api
#   ✓ Step 5: flight_search_api
#   ✓ Step 7: booking_api
#   ✓ Step 9: booking_api
#   ✓ Step 10: booking_api
#   ✓ Step 11: booking_api
#   ✓ Step 12: email_api
#   ✓ Step 13: email_api
#   ✓ Step 14: email_api
#   ✓ Step 15: email_api
#   ✓ Step 16: booking_api
#   ✓ Step 17: email_api
#
# ======================================================================
# [Trace(trace_id=tr-083832c3ea810694ddcb46a63d2e6c61), Trace(trace_id=tr-2b2de2e899f965f44c5012bd89c1f0b5), Trace(trace_id=tr-a0f7ac6349e69b4aacfa00196c9903c9), Trace(trace_id=tr-aa05d5339b4c75ab132a7a24444e6e9a), Trace(trace_id=tr-f194a1171b1260b66caaa0c268430074)]

# %% [markdown]
# ## 🧪 Experiment: Complete Workflow with Multiple Scenarios
#
# Let's run the complete workflow (Plan → Evaluate → Execute) on multiple tasks:

# %%
# Define test scenarios (using only available tools)
test_scenarios = [
    (
        "Book a flight and hotel for vacation",
        ["flight_search_api", "booking_api", "hotel_search_api", "email_api"]
    ),
    (
        "Schedule team meeting and send invites",
        ["calendar_api", "email_api"]
    ),
    (
        "Plan business trip with flight, hotel, and calendar",
        ["flight_search_api", "booking_api", "hotel_search_api", "calendar_api", "email_api"]
    ),
]

# Run complete workflow for all scenarios
results = []
for task, resources in test_scenarios:
    result = run_complete_workflow(task, resources)
    results.append({
        "task": task,
        "plan_score": result["evaluation"]["score"],
        "plan_quality": result["evaluation"]["quality"],
        "exec_success_rate": result["execution"]["successful_steps"] / result["execution"]["total_steps"] * 100
    })

# Summary
print("\n" + "=" * 70)
print("📊 EXPERIMENT SUMMARY")
print("=" * 70)
avg_plan_score = sum(r["plan_score"] for r in results) / len(results)
avg_exec_rate = sum(r["exec_success_rate"] for r in results) / len(results)

print(f"\nAverage Plan Quality Score: {avg_plan_score:.1f}/5")
print(f"Average Execution Success Rate: {avg_exec_rate:.0f}%\n")

print("Detailed Results:")
print(f"{'Task':<50} | {'Plan Quality':<12} | {'Score':<5} | {'Exec %':<6}")
print("-" * 70)
for r in results:
    print(f"{r['task'][:48]:<50} | {r['plan_quality']:12s} | {r['plan_score']}/5   | {r['exec_success_rate']:.0f}%")
print("=" * 70)
# Out:
# ======================================================================
# Task Goal: Book a flight and hotel for vacation
# Available Resources: ['flight_search_api', 'booking_api', 'hotel_search_api', 'email_api']
# ======================================================================
#
# 📝 Creating plan...
#
# ✓ Plan created:
#   1. Define trip parameters (no API): Determine traveler details (names as on passports), preferred departure/return dates, origin and destination cities/airports, cabin class, baggage needs, seating preferences, hotel dates, location preferences, star rating, budget ceilings for flight and hotel, and acceptable layover limits.
#   2. Search flights (flight_search_api): Query round-trip options with origin, destination, date range (include +/- 1–2 days for flexibility), passenger count, cabin class, max layovers, preferred departure time windows, and budget cap. Request results with total price, fare rules, baggage allowance, change/cancel policies, layover durations, and hold/lock options.
#   3. Filter and shortlist flights (no API): Rank flights by total travel time, layover quality, on-time performance (if provided), and price. Create a top 3–5 shortlist with fare class codes and booking deadlines.
#   4. Verify fare availability and final pricing (flight_search_api): Re-price each shortlisted flight to confirm live availability and final total including taxes, fees, and baggage. Capture fare rules and ticketing time limits.
#   5. Collect traveler info (no API): Gather full names, DOB, gender (if required), passport numbers/expiry, known traveler numbers, frequent flyer numbers, seat and meal preferences, contact email/phone, and billing address.
#   6. Hold or lock selected flight (booking_api): If supported, place a free/low-cost hold on the best flight from the shortlist using traveler details to secure fare while hotel is finalized. Record hold expiration timestamp and PNR/record locator.
#   7. Search hotels (hotel_search_api): Query hotels for the destination and stay dates with filters for location (neighborhood/proximity to attractions or transit), star rating, amenities (Wi‑Fi, pool, gym, breakfast), room type/bed configuration, free cancellation window, and budget. Request results with nightly rate, taxes/fees, cancellation policy, and total stay cost.
#   8. Filter and shortlist hotels (no API): Rank options by location, total cost, cancellation flexibility, guest rating, and amenities. Create a top 3 shortlist with room types and cancellation deadlines.
#   9. Verify room availability and final pricing (hotel_search_api): Re-check live availability and total cost for each shortlisted hotel and room type, including resort fees and taxes. Confirm cancellation terms and payment requirements (prepay vs pay at property).
#   10. Select final flight and hotel (no API): Choose the optimal combination balancing schedule, total trip cost, and policies. Ensure flight hold window covers hotel booking step; if no hold, prioritize flight purchase first to avoid fare change.
#   11. Book flight (booking_api): Submit booking for selected itinerary with traveler details, seat selections, baggage, payment details, and frequent flyer numbers. Request immediate ticketing. Capture booking reference (PNR), e-ticket numbers, fare rules, and receipts.
#   12. Book hotel (booking_api): Using the hotel’s rate plan from hotel_search_api, complete reservation with guest names, room type, special requests, loyalty number, payment details (or guarantee), and note cancellation policy. Capture confirmation number, rate details, and cancellation deadline.
#   13. Send confirmation email (email_api): Compile itinerary summary including flight details (PNR, e-tickets, times, terminals, baggage), hotel details (confirmation number, address, check-in/out times, cancellation deadline), total costs, and important policies. Send to traveler’s email.
#   14. Add calendar invites (email_api): Send .ics calendar invites for each flight segment and hotel stay with confirmation numbers, check-in/out times, and location links.
#   15. Set reminders (email_api): Schedule reminder emails for key dates: flight check-in window opening, hotel cancellation deadline, hold expiration (if any), and 72/24 hours pre-departure checklist.
#   16. Post-booking checks (flight_search_api and hotel_search_api): Verify booking status 24 hours later to confirm ticketing and hotel confirmation remain active; check for schedule changes or rate issues. If discrepancies, escalate via booking_api support endpoints.
#   17. Seat and special requests follow-up (booking_api): If seats not assigned, use booking_api to select preferred seats; add meal requests or special assistance as needed.
#   18. Store documents (no API): Save PDFs of e-tickets, receipts, and hotel confirmations; note passport/visa/ESTA requirements and vaccination or entry rules for the destination.
#   19. Contingency monitoring (flight_search_api): Set up alerts for schedule changes or significant fare drops for post-purchase price protection if supported by fare rules; notify traveler via email_api if action is advised.
#   20. Final pre-trip email (email_api): 24 hours before departure, send consolidated email with check-in links, terminal info, baggage allowances, hotel check-in instructions, and local transport tips.
#
# ⚖️  Evaluating plan quality...
#
# ✓ Quality: EXCELLENT (Score: 5/5)
#   Assessment: The plan demonstrates an excellent understanding of the task "Book a flight and hotel for vacation" and the available tools. It is highly detailed, co...
#
# 🔧 Executing plan with tools...
#
#   Executing 20 steps...
#   └─ Step 1/20: Define trip parameters (no API): Determine traveler details ...
#   └─ Step 2/20: Search flights (flight_search_api): Query round-trip options...
#      ✓ Used flight_search_api
#   └─ Step 3/20: Filter and shortlist flights (no API): Rank flights by total...
#   └─ Step 4/20: Verify fare availability and final pricing (flight_search_ap...
#      ✓ Used flight_search_api
#   └─ Step 5/20: Collect traveler info (no API): Gather full names, DOB, gend...
#   └─ Step 6/20: Hold or lock selected flight (booking_api): If supported, pl...
#      ✓ Used booking_api
#   └─ Step 7/20: Search hotels (hotel_search_api): Query hotels for the desti...
#      ✓ Used hotel_search_api
#   └─ Step 8/20: Filter and shortlist hotels (no API): Rank options by locati...
#   └─ Step 9/20: Verify room availability and final pricing (hotel_search_api...
#      ✓ Used hotel_search_api
#   └─ Step 10/20: Select final flight and hotel (no API): Choose the optimal c...
#   └─ Step 11/20: Book flight (booking_api): Submit booking for selected itine...
#      ✓ Used booking_api
#   └─ Step 12/20: Book hotel (booking_api): Using the hotel’s rate plan from h...
#   └─ Step 13/20: Send confirmation email (email_api): Compile itinerary summa...
#      ✓ Used email_api
#   └─ Step 14/20: Add calendar invites (email_api): Send .ics calendar invites...
#      ✓ Used email_api
#   └─ Step 15/20: Set reminders (email_api): Schedule reminder emails for key ...
#      ✓ Used email_api
#   └─ Step 16/20: Post-booking checks (flight_search_api and hotel_search_api)...
#      ✓ Used flight_search_api
#   └─ Step 17/20: Seat and special requests follow-up (booking_api): If seats ...
#      ✓ Used booking_api
#   └─ Step 18/20: Store documents (no API): Save PDFs of e-tickets, receipts, ...
#   └─ Step 19/20: Contingency monitoring (flight_search_api): Set up alerts fo...
#      ✓ Used flight_search_api
#   └─ Step 20/20: Final pre-trip email (email_api): 24 hours before departure,...
#      ✓ Used email_api
#
# ✓ Execution: 20/20 steps successful
#   ✓ Step 2: flight_search_api
#   ✓ Step 4: flight_search_api
#   ✓ Step 6: booking_api
#   ✓ Step 7: hotel_search_api
#   ✓ Step 9: hotel_search_api
#   ✓ Step 11: booking_api
#   ✓ Step 13: email_api
#   ✓ Step 14: email_api
#   ✓ Step 15: email_api
#   ✓ Step 16: flight_search_api
#   ✓ Step 17: booking_api
#   ✓ Step 19: flight_search_api
#   ✓ Step 20: email_api
#
# ======================================================================
#
#
# ======================================================================
# Task Goal: Schedule team meeting and send invites
# Available Resources: ['calendar_api', 'email_api']
# ======================================================================
#
# 📝 Creating plan...
#
# ✓ Plan created:
#   1. Gather meeting details (topic, desired duration, time window options, required attendees, optional attendees) — no API call
#   2. Check attendee availability for proposed time windows using calendar_api: query free/busy for all required attendees over the specified date range
#   3. Identify the earliest time slot that fits the duration and is free for all required attendees; if none, pick the slot with least conflicts and note conflicts
#   4. Create the calendar event using calendar_api: set title, agenda/description, date/time, duration, organizer, location/virtual link, and mark required vs. optional attendees
#   5. Add conferencing details using calendar_api (e.g., generate video meeting link) and attach to the event
#   6. Set event reminders using calendar_api (e.g., email reminder 24 hours before, popup 10 minutes before)
#   7. Send calendar invites to all attendees via calendar_api so they receive standard calendar invites with RSVP support
#   8. Send a confirmation email to all required and optional attendees using email_api: include summary, agenda, final date/time, conferencing link, attachments or pre-reads, and RSVP instructions
#   9. If any required attendee was unavailable, send a separate follow-up via email_api proposing alternative times and asking for constraints; schedule a hold on the calendar using calendar_api if needed
#   10. Monitor RSVPs via calendar_api over the next 24–48 hours; if key declines occur, use calendar_api to propose a new time to all and update the event
#   11. On confirmation, use email_api to send a reminder with agenda and materials 24 hours before the meeting
#   12. After scheduling is finalized, use calendar_api to lock the event details and update any changes to attendees automatically
#
# ⚖️  Evaluating plan quality...
#
# ✓ Quality: EXCELLENT (Score: 5/5)
#   Assessment: The plan demonstrates excellent quality across all criteria:
#
# **1. Logical Step Ordering:** The steps are ordered logically and sequentially. It start...
#
# 🔧 Executing plan with tools...
#
#   Executing 12 steps...
#   └─ Step 1/12: Gather meeting details (topic, desired duration, time window...
#   └─ Step 2/12: Check attendee availability for proposed time windows using ...
#      ✓ Used calendar_api
#   └─ Step 3/12: Identify the earliest time slot that fits the duration and i...
#      ✓ Used calendar_api
#   └─ Step 4/12: Create the calendar event using calendar_api: set title, age...
#      ✓ Used calendar_api
#   └─ Step 5/12: Add conferencing details using calendar_api (e.g., generate ...
#      ✓ Used calendar_api
#   └─ Step 6/12: Set event reminders using calendar_api (e.g., email reminder...
#      ✓ Used calendar_api
#   └─ Step 7/12: Send calendar invites to all attendees via calendar_api so t...
#      ✓ Used calendar_api
#   └─ Step 8/12: Send a confirmation email to all required and optional atten...
#      ✓ Used email_api
#   └─ Step 9/12: If any required attendee was unavailable, send a separate fo...
#   └─ Step 10/12: Monitor RSVPs via calendar_api over the next 24–48 hours; if...
#      ✓ Used calendar_api
#   └─ Step 11/12: On confirmation, use email_api to send a reminder with agend...
#      ✓ Used email_api
#   └─ Step 12/12: After scheduling is finalized, use calendar_api to lock the ...
#      ✓ Used calendar_api
#
# ✓ Execution: 12/12 steps successful
#   ✓ Step 2: calendar_api
#   ✓ Step 3: calendar_api
#   ✓ Step 4: calendar_api
#   ✓ Step 5: calendar_api
#   ✓ Step 6: calendar_api
#   ✓ Step 7: calendar_api
#   ✓ Step 8: email_api
#   ✓ Step 10: calendar_api
#   ✓ Step 11: email_api
#   ✓ Step 12: calendar_api
#
# ======================================================================
#
#
# ======================================================================
# Task Goal: Plan business trip with flight, hotel, and calendar
# Available Resources: ['flight_search_api', 'booking_api', 'hotel_search_api', 'calendar_api', 'email_api']
# ======================================================================
#
# 📝 Creating plan...
#
# ✓ Plan created:
#   1. Use flight_search_api to search round-trip flights matching trip dates, preferred departure/arrival airports, cabin class, and time windows; filter by total travel time, layovers, and price; select top 2–3 candidate flights.
#   2. Use booking_api to hold or reserve the selected outbound and return flights (place a temporary hold if supported) under traveler’s legal name, DOB, TSA/Known Traveler Number, and loyalty numbers; confirm fare rules and baggage allowance.
#   3. Use hotel_search_api to search accommodations near the meeting location with specified dates, budget, rating threshold, and amenities (Wi‑Fi, workspace, breakfast, cancellation policy); shortlist 2–3 options based on total price and proximity.
#   4. Use booking_api to book the chosen hotel with traveler details and payment method; request late check-in if arrival is evening and include loyalty number; ensure flexible cancellation if required.
#   5. Use booking_api to finalize the flight purchase before hold expires; select seats per preference and add airline loyalty number; purchase checked bag or priority boarding if needed.
#   6. Use calendar_api to create calendar events: outbound flight (with confirmation number, terminal/gate placeholder, check-in time), hotel check-in/out, meetings, local transit time buffers, and return flight; add alerts (24h, 3h, 1h before).
#   7. Use calendar_api to add a shared itinerary calendar or invite relevant colleagues to meeting events; include hotel address, check-in policy, and flight record locators in event descriptions.
#   8. Use email_api to send the traveler a consolidated itinerary email including flight details, hotel confirmation, addresses/maps links, check-in instructions, and calendar file attachments; CC assistant/manager if applicable.
#   9. Use calendar_api to set travel hold blocks around flights and key meetings to prevent conflicting bookings; mark as “Busy.”
#   10. Use email_api to subscribe/enroll the traveler in airline/hotel trip alerts if supported, or send instructions and links for mobile app check-in and real-time notifications.
#   11. Use calendar_api to add expense reminders post-trip (receipt upload tasks) and per-diem notes; set reminders for the last travel day and one day after return.
#   12. Use booking_api to add special requests or ancillaries post-booking if needed (meal preference, accessibility, late checkout); confirm changes and update calendar event notes accordingly.
#   13. Use email_api to send final confirmation with any updates, including a PDF of receipts/confirmations and a summary of cancellation/change policies and key deadlines.
#
# ⚖️  Evaluating plan quality...
#
# ✓ Quality: EXCELLENT (Score: 5/5)
#   Assessment: The AI agent has produced an excellent plan for organizing a business trip. It demonstrates a clear understanding of the task goal and effectively uti...
#
# 🔧 Executing plan with tools...
#
#   Executing 13 steps...
#   └─ Step 1/13: Use flight_search_api to search round-trip flights matching ...
#      ✓ Used flight_search_api
#   └─ Step 2/13: Use booking_api to hold or reserve the selected outbound and...
#      ✓ Used booking_api
#   └─ Step 3/13: Use hotel_search_api to search accommodations near the meeti...
#      ✓ Used hotel_search_api
#   └─ Step 4/13: Use booking_api to book the chosen hotel with traveler detai...
#      ✓ Used booking_api
#   └─ Step 5/13: Use booking_api to finalize the flight purchase before hold ...
#      ✓ Used booking_api
#   └─ Step 6/13: Use calendar_api to create calendar events: outbound flight ...
#      ✓ Used calendar_api
#   └─ Step 7/13: Use calendar_api to add a shared itinerary calendar or invit...
#      ✓ Used calendar_api
#   └─ Step 8/13: Use email_api to send the traveler a consolidated itinerary ...
#      ✓ Used email_api
#   └─ Step 9/13: Use calendar_api to set travel hold blocks around flights an...
#      ✓ Used calendar_api
#   └─ Step 10/13: Use email_api to subscribe/enroll the traveler in airline/ho...
#      ✓ Used email_api
#   └─ Step 11/13: Use calendar_api to add expense reminders post-trip (receipt...
#      ✓ Used calendar_api
#   └─ Step 12/13: Use booking_api to add special requests or ancillaries post-...
#      ✓ Used booking_api
#   └─ Step 13/13: Use email_api to send final confirmation with any updates, i...
#      ✓ Used email_api
#
# ✓ Execution: 13/13 steps successful
#   ✓ Step 1: flight_search_api
#   ✓ Step 2: booking_api
#   ✓ Step 3: hotel_search_api
#   ✓ Step 4: booking_api
#   ✓ Step 5: booking_api
#   ✓ Step 6: calendar_api
#   ✓ Step 7: calendar_api
#   ✓ Step 8: email_api
#   ✓ Step 9: calendar_api
#   ✓ Step 10: email_api
#   ✓ Step 11: calendar_api
#   ✓ Step 12: booking_api
#   ✓ Step 13: email_api
#
# ======================================================================
#
#
# ======================================================================
# 📊 EXPERIMENT SUMMARY
# ======================================================================
#
# Average Plan Quality Score: 5.0/5
# Average Execution Success Rate: 100%
#
# Detailed Results:
# Task                                               | Plan Quality | Score | Exec %
# ----------------------------------------------------------------------
# Book a flight and hotel for vacation               | excellent    | 5/5   | 100%
# Schedule team meeting and send invites             | excellent    | 5/5   | 100%
# Plan business trip with flight, hotel, and calen   | excellent    | 5/5   | 100%
# ======================================================================
# [Trace(trace_id=tr-2568740e126d630c991035ce07288c61), Trace(trace_id=tr-301d90a01045672c9e11ae4beb5f5972), Trace(trace_id=tr-667f42807c78cf543b2beddde05378b1), Trace(trace_id=tr-22883ed584f81d58191e3ac11ea35d1a), Trace(trace_id=tr-8ba5d37242114d23107a8e08e5363bd3), Trace(trace_id=tr-fe213a2db89ead9662ae11fe6b9c7d23), Trace(trace_id=tr-09f313eb5484186afde0bd8fddb1308c), Trace(trace_id=tr-c7bfd43ab764083e851c3c22db8c8f39), Trace(trace_id=tr-584e17d2d842cc9ab85f4507e2db19ac), Trace(trace_id=tr-145d483f19c022619a35e8cffe42ab60)]

# %% [markdown]
# ## 🎨 Customization
#
# ### Modify Evaluation Criteria
#
# The judge's evaluation criteria are defined in `prompts.py`. You can view them:

# %%
print("Current Judge Instructions:")
print("=" * 70)
print(get_judge_instructions())
print("=" * 70)
# Out:
# Current Judge Instructions:
# ======================================================================
# You are an expert evaluator assessing AI agent planning capabilities.
#
# You will receive a trace showing the agent's planning process:
# {{ trace }}
#
# Evaluate the plan's quality by considering these criteria:
#
# 1. **Logical Step Ordering**: Are the steps in the correct sequence? Does each step build on previous ones?
# 2. **Tool Validity**: Does the plan only use valid, available tools/resources? No hallucinated tools?
# 3. **Task Sufficiency**: Will this plan actually accomplish the stated goal? Are all necessary steps included?
# 4. **Efficiency**: Is the approach optimal, or are there unnecessary steps or redundant actions?
#
# Assign a quality rating:
#
# - **excellent**: Clear structure, logical flow, all steps necessary and sufficient, optimal efficiency
# - **good**: Well-structured with minor inefficiencies or small improvements possible
# - **adequate**: Basic plan that works but lacks optimization or has minor logical issues
# - **poor**: Significant gaps, illogical ordering, or uses invalid tools
# - **very_poor**: Fundamentally flawed, cannot achieve goal, or relies heavily on unavailable resources
#
# Provide your evaluation as:
# - Value: One of [excellent, good, adequate, poor, very_poor]
# - Rationale: Detailed explanation including:
#   - Strengths of the plan
#   - Weaknesses or gaps identified
#   - Specific suggestions for improvement
#   - Assessment of each criterion (ordering, validity, sufficiency, efficiency)
#
# ======================================================================

# %% [markdown]
# ## 📚 Key Concepts Summary
#
# ### Complete Workflow: Plan → Evaluate → Execute
#
# This tutorial demonstrates the full multi-agent planning lifecycle:
#
# 1. **Planning**: Agent creates multi-step plan using LLM
# 2. **Evaluation**: Judge assesses plan quality on 4 dimensions
# 3. **Execution**: Executor actually calls tools using LLM function calling
#
# ### MLflow Tracing
# - Automatically captures planning inputs/outputs
# - Tracks execution time and metadata
# - Creates parent-child relationships for nested calls
# - Records every tool call with parameters and results
#
# ### MLflow Judge
# - Created with `make_judge()`
# - Evaluates on 4 dimensions: ordering, validity, sufficiency, efficiency
# - Returns quality level + detailed rationale
#
# ### Tool Execution with LLM Function Calling
# - **Dynamic Tool Selection**: LLM chooses which tool to use for each step
# - **Parameter Generation**: LLM determines appropriate parameters
# - **Context Passing**: Results from earlier steps inform later steps
# - **Automatic Tracing**: Every tool call is traced in MLflow
#
# ### Quality Assessment Criteria
# - **Logical Ordering**: Sequential flow of steps
# - **Tool Validity**: Only uses available resources
# - **Task Sufficiency**: Complete plan to achieve goal
# - **Efficiency**: Optimal approach without redundancy
#
# ### Available Tools (5 Simulated APIs)
# - `flight_search_api`: Search for flights
# - `booking_api`: Book flights
# - `hotel_search_api`: Search for hotels
# - `calendar_api`: Manage calendar events
# - `email_api`: Send emails

# %%
example_prompt = get_planning_prompt(
    "Book a flight to Boston",
    ["flight_search_api", "booking_api"]
)

print("Example Planning Prompt:")
print("=" * 70)
print(example_prompt)
print("=" * 70)

# %% [markdown]
# ## 📊 Quality Levels Explained
#
# The judge evaluates plans on a 5-point scale:
#
# | Quality Level | Score | Description |
# |--------------|-------|-------------|
# | **Excellent** | 5 | Clear structure, logical flow, all steps necessary and sufficient, optimal efficiency |
# | **Good** | 4 | Well-structured with minor inefficiencies or small improvements possible |
# | **Adequate** | 3 | Basic plan that works but lacks optimization or has minor logical issues |
# | **Poor** | 2 | Significant gaps, illogical ordering, or uses invalid tools |
# | **Very Poor** | 1 | Fundamentally flawed, cannot achieve goal, or relies heavily on unavailable resources |

# %% [markdown]
# ## 🚀 Next Steps
#
# 1. **Explore MLflow UI**: Run `mlflow ui` to see detailed traces
# 2. **Modify Prompts**: Edit `prompts.py` to change evaluation criteria
# 3. **Try Different Models**: Experiment with different agent and judge models
# 4. **Add More Resources**: Expand the `available_resources` list
# 5. **Complex Tasks**: Try multi-domain tasks requiring diverse resources
# 6. **Apply to Your Use Case**: Adapt this pattern for your own planning evaluations
#
# ## 📖 Resources
#
# - [MLflow GenAI Judges Documentation](https://mlflow.org/docs/latest/llms/llm-evaluate/index.html)
# - [Tool Selection Judge](../tools_selection/tool_selection_judge.ipynb) - Related tutorial
# - [Agent Planning Judge README](README.md)
